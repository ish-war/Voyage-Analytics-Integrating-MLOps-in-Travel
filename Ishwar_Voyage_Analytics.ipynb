# %% [markdown]
# <a href="https://colab.research.google.com/github/ish-war/Voyage-Analytics-Integrating-MLOps-in-Travel/blob/main/Ishwar_Voyage_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![earning-opportunity-with-tour-and-travel-agency-in-patna.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Project Name**    - Voyage Analytics: Integrating MLOps for Predictive and Recommender Systems in Travel Productionization of ML Systems

# %% [markdown]
# ##### **Project Type**    - Productionization of ML Systems
# ##### **Contribution**    -
# ##### **Name -**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# **Voyage Analytics: Integrating MLOps for Predictive and Recommender Systems in Travel**
#
# The travel and tourism industry is rapidly evolving, with travelers increasingly seeking personalized and data-driven experiences. To address these demands, this project, "Voyage Analytics: Integrating MLOps for Predictive and Recommender Systems in Travel," aims to harness the power of machine learning and modern MLOps practices to enhance travel-related decision-making and customer experiences. By integrating diverse datasets and deploying sophisticated models, the project seeks to provide actionable insights and scalable solutions for the travel industry.
#
# **Datasets and Objectives**
#
# The project utilizes three key datasets: Users, Flights, and Hotels. Each dataset offers unique perspectives on travel behaviors and preferences:
#
# 1. **Users Dataset**: Contains user identifiers, associated companies, names, gender, and age. This data helps in understanding user demographics and segmenting the audience for personalized recommendations.
#
# 2. **Flights Dataset**: Includes details such as travel identifiers, user codes, flight origins and destinations, flight types, prices, durations, distances, agencies, and dates. This dataset is crucial for predicting flight prices and analyzing travel patterns.
#
# 3. **Hotels Dataset**: Provides information on travel identifiers, user codes, hotel names, locations, duration of stays, daily rates, total costs, and booking dates. This dataset supports the development of recommendations for hotel stays and pricing predictions.
#
# **Project Objectives**
#
# 1. **Regression Model Development**: The primary goal is to build a regression model to predict flight prices based on the Flights dataset. This involves feature selection, model training, and validation to ensure accuracy and reliability. By analyzing historical flight data, the model will forecast future prices and assist travelers in making informed decisions.
#
# 2. **REST API for Regression Model**: To facilitate real-time price predictions, a REST API will be developed using Flask. This API will enable users and travel agencies to access the flight price prediction model through a web interface, offering dynamic and scalable price forecasting capabilities.
#
# 3. **Containerization**: The flight price prediction model will be packaged and deployed using Docker. This step ensures that the model is portable, consistent, and can be easily deployed across various environments without compatibility issues.
#
# 4. **Kubernetes for Scalability**: Kubernetes will be used to manage the deployment of the model, providing scalability and efficient load handling. This orchestration tool will help manage the model's availability and performance, accommodating varying user demands and system loads.
#
# 5. **Automated Workflows with Apache Airflow**: Automated workflows will be designed and implemented using Apache Airflow. Directed Acyclic Graphs (DAGs) will be created to manage data pipelines and orchestrate complex workflows, ensuring smooth and reliable operations for data processing and model updates.
#
# 6. **CI/CD Pipeline with Jenkins**: A Continuous Integration/Continuous Deployment (CI/CD) pipeline will be established using Jenkins. This pipeline will automate the deployment process, ensuring consistent and reliable updates to the model and related components, and streamlining the overall development workflow.
#
# **Technical Execution and Evaluation**
#
# The project will focus on the technical accuracy of the regression, classification, and recommendation models. Proper implementation of the REST API, Docker, Kubernetes, Apache Airflow, and Jenkins will be critical. MLFlow will be used for model tracking to monitor performance and ensure model integrity. The project will also include a Streamlit web app for user-friendly interaction with the models.
#
# Code quality, organization, and documentation will be emphasized to ensure maintainability and clarity. A well-structured GitHub repository will be maintained, with meaningful commit messages and comprehensive README files detailing project setup, usage, and other relevant information.
#
# **Outcome and Impact**
#
# The successful completion of this project will provide the travel industry with advanced tools for predictive analytics and personalized recommendations. By integrating MLOps practices, the project will offer scalable, automated solutions for managing travel data and deploying machine learning models. The final deliverables will enhance decision-making for travelers and travel companies, leading to improved customer satisfaction and operational efficiency.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **In the dynamic travel and tourism industry, providing personalized and accurate recommendations is crucial for enhancing customer experiences. This project aims to develop a machine learning system that predicts travel-related costs and provides personalized recommendations by leveraging user, flight, and hotel datasets. By integrating MLOps practices, the project will ensure scalable, reliable, and automated deployment of these predictive models, ultimately improving decision-making for both customers and travel companies.**

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
'''!pip install sentence-transformers'''
# Out:
# '!pip install sentence-transformers'

# %%
# Import Libraries
# Import Libraries
import numpy as np
import pandas as pd
from numpy import math
from numpy import loadtxt
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rcParams
'''!pip install pymysql
import pymysql
from sqlalchemy import create_engine
from sqlalchemy.pool import NullPool

import numpy as np
import seaborn as sns
from scipy.stats import *
import math

from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn import metrics
from sklearn.metrics import roc_curve
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold
from xgboost import XGBClassifier
from xgboost import XGBRFClassifier
from sklearn.tree import export_graphviz

# !pip install shap==0.40.0
import shap
import graphviz
sns.set_style('darkgrid')'''

import warnings
warnings.filterwarnings('ignore')
# Out:
# <ipython-input-2-745d36f3a021>:5: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   from numpy import math

# %% [markdown]
# ### Dataset Loading

# %%
#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load Dataset
users = pd.read_csv('/content/users.csv')
flights = pd.read_csv('/content/flights.csv')
hotels = pd.read_csv('/content/hotels.csv')

# %% [markdown]
# ### Dataset First View

# %%
users.head()
# Out:
#    code company             name  gender  age
# 0     0    4You        Roy Braun    male   21
# 1     1    4You   Joseph Holsten    male   37
# 2     2    4You    Wilma Mcinnis  female   48
# 3     3    4You     Paula Daniel  female   23
# 4     4    4You  Patricia Carson  female   44

# %%
flights.head()
# Out:
#    travelCode  userCode                from                  to  flightType  \
# 0           0         0         Recife (PE)  Florianopolis (SC)  firstClass
# 1           0         0  Florianopolis (SC)         Recife (PE)  firstClass
# 2           1         0       Brasilia (DF)  Florianopolis (SC)  firstClass
# 3           1         0  Florianopolis (SC)       Brasilia (DF)  firstClass
# 4           2         0        Aracaju (SE)       Salvador (BH)  firstClass
#
#      price  time  distance       agency        date
# 0  1434.38  1.76    676.53  FlyingDrops  09/26/2019
# 1  1292.29  1.76    676.53  FlyingDrops  09/30/2019
# 2  1487.52  1.66    637.56      CloudFy  10/03/2019
# 3  1127.36  1.66    637.56      CloudFy  10/04/2019
# 4  1684.05  2.16    830.86      CloudFy  10/10/2019

# %%
hotels.head()
# Out:
#    travelCode  userCode     name               place  days   price    total  \
# 0           0         0  Hotel A  Florianopolis (SC)     4  313.02  1252.08
# 1           2         0  Hotel K       Salvador (BH)     2  263.41   526.82
# 2           7         0  Hotel K       Salvador (BH)     3  263.41   790.23
# 3          11         0  Hotel K       Salvador (BH)     4  263.41  1053.64
# 4          13         0  Hotel A  Florianopolis (SC)     1  313.02   313.02
#
#          date
# 0  09/26/2019
# 1  10/10/2019
# 2  11/14/2019
# 3  12/12/2019
# 4  12/26/2019

# %%
# Dataset Rows & Columns count
# Check the shape of the datasets
print(users.shape)
print(flights.shape)
print(hotels.shape)
# Out:
# (1340, 5)
# (271888, 10)
# (40552, 8)

# %% [markdown]
# ### Dataset merging

# %%
merge1 = pd.merge(flights,hotels, on = ['travelCode'], how = 'inner')
merge1.head(10)
# Out:
#    travelCode  userCode_x                from                  to  flightType  \
# 0           0           0         Recife (PE)  Florianopolis (SC)  firstClass
# 1           0           0  Florianopolis (SC)         Recife (PE)  firstClass
# 2           2           0        Aracaju (SE)       Salvador (BH)  firstClass
# 3           2           0       Salvador (BH)        Aracaju (SE)  firstClass
# 4           7           0        Aracaju (SE)       Salvador (BH)    economic
# 5           7           0       Salvador (BH)        Aracaju (SE)    economic
# 6          11           0       Brasilia (DF)       Salvador (BH)     premium
# 7          11           0       Salvador (BH)       Brasilia (DF)     premium
# 8          13           0         Recife (PE)  Florianopolis (SC)  firstClass
# 9          13           0  Florianopolis (SC)         Recife (PE)  firstClass
#
#    price_x  time  distance       agency      date_x  userCode_y     name  \
# ...

# %%
df = pd.merge(users, merge1, left_on='code', right_on='userCode_x')
df
# Out:
#        code        company          name_x gender  age  travelCode  \
# 0         0           4You       Roy Braun   male   21           0
# 1         0           4You       Roy Braun   male   21           0
# 2         0           4You       Roy Braun   male   21           2
# 3         0           4You       Roy Braun   male   21           2
# 4         0           4You       Roy Braun   male   21           7
# ...     ...            ...             ...    ...  ...         ...
# 81099  1339  Umbrella LTDA  Paul Rodriguez   male   35      135940
# 81100  1339  Umbrella LTDA  Paul Rodriguez   male   35      135941
# 81101  1339  Umbrella LTDA  Paul Rodriguez   male   35      135941
# 81102  1339  Umbrella LTDA  Paul Rodriguez   male   35      135942
# 81103  1339  Umbrella LTDA  Paul Rodriguez   male   35      135942
#
#        userCode_x                from                  to  flightType  ...  \
# 0               0         Recife (PE)  Florianopolis (SC)  firstClass  ...
# ...

# %%
df.columns
# Out:
# Index(['code', 'company', 'name_x', 'gender', 'age', 'travelCode',
#        'userCode_x', 'from', 'to', 'flightType', 'price_x', 'time', 'distance',
#        'agency', 'date_x', 'userCode_y', 'name_y', 'place', 'days', 'price_y',
#        'total', 'date_y'],
#       dtype='object')

# %%
df.rename(columns={'price_x': 'flight_price', 'price_y': 'hotel_price', 'date_x' : 'flight_date', 'date_y' : 'hotel_date',
                   'name_x' : 'user_name', 'name_y' : 'hotel_name'}, inplace=True)

# %%
# Rename the column
#users.rename(columns={'id':'userCode','name':'user_name'},inplace=True)
#hotels.rename(columns={'name':'hotel_name','price':'hotel_price','date':'hotel_date'},inplace=True)

# %%
df.shape
# Out:
# (81104, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81104 entries, 0 to 81103
# Data columns (total 22 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   code          81104 non-null  int64
#  1   company       81104 non-null  object
#  2   user_name     81104 non-null  object
#  3   gender        81104 non-null  object
#  4   age           81104 non-null  int64
#  5   travelCode    81104 non-null  int64
#  6   userCode_x    81104 non-null  int64
#  7   from          81104 non-null  object
#  8   to            81104 non-null  object
#  9   flightType    81104 non-null  object
#  10  flight_price  81104 non-null  float64
#  11  time          81104 non-null  float64
#  12  distance      81104 non-null  float64
#  13  agency        81104 non-null  object
#  14  flight_date   81104 non-null  object
#  15  userCode_y    81104 non-null  int64
#  16  hotel_name    81104 non-null  object
#  17  place         81104 non-null  object
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
df.drop(['userCode_x'], axis=1, inplace=True)
df.drop(['userCode_y'], axis=1, inplace=True)
df.columns
# Out:
# Index(['code', 'company', 'user_name', 'gender', 'age', 'travelCode', 'from',
#        'to', 'flightType', 'flight_price', 'time', 'distance', 'agency',
#        'flight_date', 'hotel_name', 'place', 'days', 'hotel_price', 'total',
#        'hotel_date'],
#       dtype='object')

# %%
df.head()
# Out:
#    code company  user_name gender  age  travelCode                from  \
# 0     0    4You  Roy Braun   male   21           0         Recife (PE)
# 1     0    4You  Roy Braun   male   21           0  Florianopolis (SC)
# 2     0    4You  Roy Braun   male   21           2        Aracaju (SE)
# 3     0    4You  Roy Braun   male   21           2       Salvador (BH)
# 4     0    4You  Roy Braun   male   21           7        Aracaju (SE)
#
#                    to  flightType  flight_price  time  distance       agency  \
# 0  Florianopolis (SC)  firstClass       1434.38  1.76    676.53  FlyingDrops
# 1         Recife (PE)  firstClass       1292.29  1.76    676.53  FlyingDrops
# 2       Salvador (BH)  firstClass       1684.05  2.16    830.86      CloudFy
# 3        Aracaju (SE)  firstClass       1531.92  2.16    830.86      CloudFy
# 4       Salvador (BH)    economic        964.83  2.16    830.86      CloudFy
#
#   flight_date hotel_name               place  days  hotel_price    total  \
# ...

# %%
# Dataset Rows & Columns count
#all_data.shape
# Out:
# (81104, 21)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81104 entries, 0 to 81103
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   travelCode   81104 non-null  int64
#  1   userCode     81104 non-null  int64
#  2   from         81104 non-null  object
#  3   to           81104 non-null  object
#  4   flightType   81104 non-null  object
#  5   price        81104 non-null  float64
#  6   time         81104 non-null  float64
#  7   distance     81104 non-null  float64
#  8   agency       81104 non-null  object
#  9   date         81104 non-null  object
#  10  code         81104 non-null  int64
#  11  company      81104 non-null  object
#  12  user_name    81104 non-null  object
#  13  gender       81104 non-null  object
#  14  age          81104 non-null  int64
#  15  hotel_name   81104 non-null  object
#  16  place        81104 non-null  object
#  17  days         81104 non-null  int64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81104 entries, 0 to 81103
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   code          81104 non-null  int64
#  1   company       81104 non-null  object
#  2   user_name     81104 non-null  object
#  3   gender        81104 non-null  object
#  4   age           81104 non-null  int64
#  5   travelCode    81104 non-null  int64
#  6   from          81104 non-null  object
#  7   to            81104 non-null  object
#  8   flightType    81104 non-null  object
#  9   flight_price  81104 non-null  float64
#  10  time          81104 non-null  float64
#  11  distance      81104 non-null  float64
#  12  agency        81104 non-null  object
#  13  flight_date   81104 non-null  object
#  14  hotel_name    81104 non-null  object
#  15  place         81104 non-null  object
#  16  days          81104 non-null  int64
#  17  hotel_price   81104 non-null  float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# code            0
# company         0
# user_name       0
# gender          0
# age             0
# travelCode      0
# from            0
# to              0
# flightType      0
# flight_price    0
# time            0
# distance        0
# agency          0
# flight_date     0
# hotel_name      0
# place           0
# days            0
# hotel_price     0
# total           0
# hotel_date      0
# dtype: int64

# %%
# Visualizing the missing values
plt.figure(figsize=(8,6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title("Missing Values Heatmap")
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# ### Insights from the Dataset
#
# #### Users Dataset:
# 1. **Structure**:
#    - The dataset contains columns for user identifier (`code`), associated company (`company`), user name (`name`), gender (`gender`), and age (`age`).
#
# 2. **Statistics**:
#    - **Age Distribution**: The users' ages range widely, giving a good spread across different age groups.
#    - **Gender Distribution**: There is a notable distribution between different genders.
#    - **Company Affiliation**: Users are associated with various companies, which could potentially be used to identify trends related to company-based travel preferences.
#
# 3. **Potential Features**:
#    - Categorical encoding of `company` and `gender`.
#    - Age as a direct numerical feature.
#
# 4. **No Missing Values**:
#    - This simplifies preprocessing as no imputation is needed.
#
# #### Flights Dataset:
# 1. **Structure**:
#    - Contains columns for travel identifier (`travelCode`), user identifier (`userCode`), origin (`from`), destination (`to`), flight type (`flightType`), price (`price`), duration (`time`), distance (`distance`), agency (`agency`), and date (`date`).
#
# 2. **Statistics**:
#    - **Price Distribution**: Shows the range and central tendencies of flight prices.
#    - **Flight Duration and Distance**: Insights into average flight durations and distances covered.
#    - **Flight Type and Agency Distribution**: Understanding the popularity and distribution of different flight types and agencies.
#
# 3. **Time-Based Features**:
#    - Created features such as `travel_month` and `travel_day` to capture seasonal and daily variations in travel.
#
# 4. **Relationships**:
#    - Positive correlations between price, distance, and duration, indicating that longer and farther flights tend to be more expensive.
#
# 5. **No Missing Values**:
#    - Ensures data consistency and simplifies the preprocessing steps.
#
# #### Hotels Dataset:
# 1. **Structure**:
#    - Contains columns for travel identifier (`travelCode`), user identifier (`userCode`), hotel name (`name`), location (`place`), number of days stayed (`days`), price per day (`price`), total price for the stay (`total`), and booking date (`date`).
#
# 2. **Statistics**:
#    - **Price Distribution**: The range of hotel prices per day and total costs for stays.
#    - **Stay Duration**: Insights into how long users tend to stay at hotels.
#    - **Location Distribution**: Identifies the most common hotel locations.
#
# 3. **Time-Based Features**:
#    - Potential to create features like `booking_month` and `booking_day` to analyze seasonal booking trends.
#
# 4. **Categorical Encoding**:
#    - Categorical features such as `place` and `name` need to be encoded for model training.
#
# 5. **No Missing Values**:
#    - Simplifies preprocessing.
#
# ### Summary of Insights
# 1. **User Characteristics**:
#    - The users dataset provides valuable demographic information such as age and gender, along with company affiliations. This can help in understanding the user base and segmenting users for more personalized recommendations.
#
# 2. **Flight Patterns**:
#    - The flights dataset reveals patterns in pricing, duration, and distance of flights. Understanding these patterns is crucial for price prediction and identifying factors that influence flight costs.
#
# 3. **Hotel Preferences**:
#    - The hotels dataset sheds light on user preferences regarding hotel locations, stay duration, and pricing. These insights can be used to build a recommendation system that suggests hotels based on user preferences and historical data.
#
# 4. **No Missing Values**:
#    - The absence of missing values across datasets means the data is complete, which aids in smoother preprocessing and reliable model training.
#
# 5. **Feature Engineering**:
#    - Creating new features from date fields and encoding categorical variables are essential steps to enhance model performance. Features like `travel_month`, `travel_day`, `booking_month`, and `booking_day` can capture temporal patterns in travel and hotel bookings.
#
# 6. **Correlations and Relationships**:
#    - Exploring relationships between numerical features through correlation heatmaps and pairplots helps in understanding the interplay between different variables, which is valuable for feature selection and engineering.
#
# With these insights, the datasets are well-understood, and the foundation is set for building robust machine learning models for regression, classification, and recommendation tasks.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['code', 'company', 'user_name', 'gender', 'age', 'travelCode', 'from',
#        'to', 'flightType', 'flight_price', 'time', 'distance', 'agency',
#        'flight_date', 'hotel_name', 'place', 'days', 'hotel_price', 'total',
#        'hotel_date'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#                code           age     travelCode  flight_price          time  \
# count  81104.000000  81104.000000   81104.000000  81104.000000  81104.000000
# mean     666.963726     42.790615   67911.794461    957.725281      1.424116
# std      391.134383     12.942576   39407.956381    362.212893      0.543071
# min        0.000000     21.000000       0.000000    301.510000      0.440000
# 25%      323.000000     32.000000   33696.750000    672.660000      1.040000
# 50%      658.000000     42.000000   67831.000000    899.600000      1.460000
# 75%     1013.000000     54.000000  102211.250000   1222.240000      1.760000
# max     1339.000000     65.000000  135942.000000   1754.170000      2.440000
#
#            distance          days   hotel_price         total
# count  81104.000000  81104.000000  81104.000000  81104.000000
# mean     548.097771      2.499679    214.439554    536.229513
# std      209.053667      1.119319     76.741832    319.329514
# ...

# %%
df.describe(include=["object"])
# Out:
#        company       user_name  gender                from  \
# count    81104           81104   81104               81104
# unique       5            1308       3                   9
# top       4You  Juanita Palmer  female  Florianopolis (SC)
# freq     28028             152   27380               17224
#
#                         to  flightType   agency flight_date hotel_name  \
# count                81104       81104    81104       81104      81104
# unique                   9           3        3         994          9
# top     Florianopolis (SC)  firstClass  CloudFy  10/03/2019    Hotel K
# freq                 17224       34608    34820         404      10188
#
#                 place  hotel_date
# count           81104       81104
# unique              9         199
# top     Salvador (BH)  10/31/2019
# freq            10188         808

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Here's a detailed description of the variables for each dataset:
#
# ### Users Dataset
#
# 1. **`code`**:
#    - **Description**: Unique identifier for each user.
#    - **Data Type**: Integer
#    - **Purpose**: Used to reference individual users.
#
# 2. **`company`**:
#    - **Description**: The company or organization associated with the user.
#    - **Data Type**: Object (String)
#    - **Purpose**: To categorize users based on their company or affiliation.
#
# 3. **`name`**:
#    - **Description**: The name of the user.
#    - **Data Type**: Object (String)
#    - **Purpose**: Provides user identity.
#
# 4. **`gender`**:
#    - **Description**: Gender of the user.
#    - **Data Type**: Object (String)
#    - **Purpose**: Used for gender-based analysis or classification.
#
# 5. **`age`**:
#    - **Description**: Age of the user.
#    - **Data Type**: Integer
#    - **Purpose**: To analyze age distribution and its impact on travel preferences.
#
# ### Flights Dataset
#
# 1. **`travelCode`**:
#    - **Description**: Identifier for each travel booking or flight.
#    - **Data Type**: Integer
#    - **Purpose**: Unique reference for each flight or booking.
#
# 2. **`userCode`**:
#    - **Description**: Identifier for the user who booked the flight.
#    - **Data Type**: Integer
#    - **Purpose**: Links flight data to the corresponding user.
#
# 3. **`from`**:
#    - **Description**: Origin of the flight.
#    - **Data Type**: Object (String)
#    - **Purpose**: Indicates the starting location of the flight.
#
# 4. **`to`**:
#    - **Description**: Destination of the flight.
#    - **Data Type**: Object (String)
#    - **Purpose**: Indicates the endpoint of the flight.
#
# 5. **`flightType`**:
#    - **Description**: Class or type of the flight (e.g., first class, economy).
#    - **Data Type**: Object (String)
#    - **Purpose**: Used to categorize flights based on their class or service level.
#
# 6. **`price`**:
#    - **Description**: Price of the flight.
#    - **Data Type**: Float
#    - **Purpose**: Represents the cost of the flight, useful for price prediction.
#
# 7. **`time`**:
#    - **Description**: Duration of the flight.
#    - **Data Type**: Float
#    - **Purpose**: Measures the time taken for the flight, useful for analysis and recommendations.
#
# 8. **`distance`**:
#    - **Description**: Distance covered by the flight.
#    - **Data Type**: Float
#    - **Purpose**: Provides information on how far the flight travels, which can influence pricing.
#
# 9. **`agency`**:
#    - **Description**: Agency through which the flight was booked.
#    - **Data Type**: Object (String)
#    - **Purpose**: To analyze booking trends based on the agency.
#
# 10. **`date`**:
#     - **Description**: Date when the flight was booked or took place.
#     - **Data Type**: Object (String) or DateTime
#     - **Purpose**: Useful for time-based analysis and trend detection.
#
# ### Hotels Dataset
#
# 1. **`travelCode`**:
#    - **Description**: Identifier for each hotel booking.
#    - **Data Type**: Integer
#    - **Purpose**: Unique reference for each hotel stay.
#
# 2. **`userCode`**:
#    - **Description**: Identifier for the user who booked the hotel.
#    - **Data Type**: Integer
#    - **Purpose**: Links hotel booking data to the corresponding user.
#
# 3. **`name`**:
#    - **Description**: Name of the hotel.
#    - **Data Type**: Object (String)
#    - **Purpose**: Provides the name of the hotel where the stay occurred.
#
# 4. **`place`**:
#    - **Description**: Location or city where the hotel is situated.
#    - **Data Type**: Object (String)
#    - **Purpose**: Indicates the geographical location of the hotel.
#
# 5. **`days`**:
#    - **Description**: Number of days the hotel was booked for.
#    - **Data Type**: Integer
#    - **Purpose**: Represents the duration of the hotel stay.
#
# 6. **`price`**:
#    - **Description**: Price per day for staying at the hotel.
#    - **Data Type**: Float
#    - **Purpose**: Indicates the daily cost of staying at the hotel, useful for price analysis.
#
# 7. **`total`**:
#    - **Description**: Total price for the entire hotel stay.
#    - **Data Type**: Float
#    - **Purpose**: Represents the overall cost of the hotel stay, calculated as `price * days`.
#
# 8. **`date`**:
#    - **Description**: Date when the hotel was booked.
#    - **Data Type**: Object (String) or DateTime
#    - **Purpose**: Useful for time-based analysis and trend detection.
#
# ### Summary
#
# - **Users Dataset**: Focuses on user identification, demographic information, and affiliations.
# - **Flights Dataset**: Covers flight details including booking identifiers, pricing, duration, and booking agency.
# - **Hotels Dataset**: Includes hotel booking information such as duration, cost, and location.
#
# These descriptions will help you understand and analyze each dataset more effectively.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

unique_values = df.nunique().sort_values(ascending = False)

# Print the unique values
print("Unique values per column:")
print(unique_values)
# Out:
# Unique values per column:
# travelCode      40552
# code             1310
# user_name        1308
# flight_date       994
# flight_price      490
# hotel_date        199
# age                45
# total              36
# distance           35
# time               33
# from                9
# to                  9
# hotel_name          9
# place               9
# hotel_price         9
# company             5
# days                4
# flightType          3
# agency              3
# gender              3
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# %%
df['gender'].value_counts()
# Out:
# gender
# female    27380
# male      27170
# none      26554
# Name: count, dtype: int64

# %%
# Replace 'none' with 'Not Specified'
df['gender'] = df['gender'].replace('none', 'Not Specified')

# %%
df['gender'].value_counts()
# Out:
# gender
# female           27380
# male             27170
# Not Specified    26554
# Name: count, dtype: int64

# %%
# Gender Distribution
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='gender')
plt.title('Gender Distribution')
plt.show()

# %%
# Age Distribution
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='age', bins=20)
plt.title('Age Distribution')
plt.show()

# %%
# Convert date columns to datetime
df['flight_date'] = pd.to_datetime(df['flight_date'])
df['hotel_date'] = pd.to_datetime(df['hotel_date'])

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Based on the information you provided, here are the manipulations and insights:
#
# ### Manipulations
#
# 1. **Renaming Columns**:
#    - `users` dataset: Renamed the columns `id` to `userCode` and `name` to `user_name`.
#    - `hotels` dataset: Renamed the columns `name` to `hotel_name`, `price` to `hotel_price`, and `date` to `hotel_date`.
#
# 2. **Merging Datasets**:
#    - Merged the `flights` and `users` datasets on the `userCode` column, resulting in `flights_users`.
#    - Merged `flights_users` with the `hotels` dataset on the `travelCode` and `userCode` columns, resulting in the final `all_data` dataset.
#
# 3. **Data Cleaning**:
#    - Checked for and found no duplicate rows in the `all_data` dataset.
#    - Replaced `none` in the `gender` column with `Not Specified`.
#    - Converted `date` and `hotel_date` columns to DateTime format for easier time-based analysis.
#
# ### Insights
#
# 1. **Data Overview**:
#    - The combined dataset `all_data` contains 81,104 rows and 21 columns.
#    - The dataset includes information about users, flights, and hotels, covering a wide range of variables such as user demographics, flight details, and hotel bookings.
#
# 2. **User Demographics**:
#    - Gender distribution: 27,380 females, 27,170 males, and 26,554 unspecified gender entries.
#    - The dataset covers users from various companies and includes users of different ages, with the age distribution ranging from 21 to 65.
#
# 3. **Flight Information**:
#    - The flights dataset includes different flight types (e.g., first class, economy), with varying prices, durations, and distances.
#    - There are nine unique origin and destination locations, indicating a range of travel routes.
#
# 4. **Hotel Bookings**:
#    - The dataset covers nine unique hotels located in different places, with varying prices and total costs depending on the number of days booked.
#
# These manipulations and insights provide a foundational understanding of the dataset, allowing for further analysis, such as predicting flight prices, understanding user preferences, and making travel recommendations.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 Based on the given data, which places are the most popular for trips, and what recommendations can be made for business growth?

# %%
df['place'].value_counts()
# Out:
# place
# Salvador (BH)          10188
# Rio de Janeiro (RJ)    10058
# Natal (RN)              9658
# Sao Paulo (SP)          9656
# Recife (PE)             8934
# Brasilia (DF)           8874
# Campo Grande (MS)       8666
# Aracaju (SE)            8410
# Florianopolis (SC)      6660
# Name: count, dtype: int64

# %%
# Chart - 1 visualization code
# Number of trips/bookings per 'place'
place_counts = df['place'].value_counts()
plt.figure(figsize=(12, 6))
place_counts.plot(kind='bar', color='salmon')
plt.title('Number of Trips per Place')
plt.xlabel('Place')
plt.ylabel('Number of Trips')
plt.xticks(rotation=45)  # Rotate labels if necessary
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is used here because it effectively displays the number of trips associated with each place. Bar charts are ideal for comparing discrete categories, making it easy to visually compare the frequency or count of items across different groups. In this case, it allows for a clear and straightforward comparison of the number of trips per place, helping to identify which places have the most or fewest trips.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Salvador (BH) is the most visited and popular place according to the chart, with more than 10,000 visits. In second place, Rio de Janeiro (RJ) received 10,000 visits.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# By observing the chart, we can understand that people most often like to visit Salvador (BH) and Rio de Janeiro (RJ). Both are located in Brazil, so promoting travel packages to these popular destinations can lead to quick sales, which is beneficial for business growth. Therefore, associated companies should focus on these areas to maximize their potential.

# %% [markdown]
# #### Chart - 2 How much a company spend on trip?

# %%
df['company'].value_counts()
# Out:
# company
# 4You             28028
# Acme Factory     15330
# Wonka Company    13412
# Umbrella LTDA    12458
# Monsters CYA     11876
# Name: count, dtype: int64

# %%
# Chart - 2 visualization code
# Average 'total' by 'company'
plt.figure(figsize=(12, 6))
sns.barplot(x='company', y='total', data=df, estimator='mean', order=df.groupby('company')['total'].mean().sort_values(ascending=False).index)
plt.title('Average Total Spend by Company')
plt.xlabel('Company')
plt.ylabel('Average Total Spend')
plt.xticks(rotation=45)  # Rotate labels if necessary
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart showing the average total spend for each company.
# It visually compares average spending across different companies, helping to identify trends and make data-driven decisions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We found that Monsters CYA has the highest average total spend.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It helps improve the customer’s trip experience.

# %% [markdown]
# #### Chart - 3 Flight price distribution by type of flight seats.

# %%
df['flightType'].value_counts()
# Out:
# flightType
# firstClass    34608
# premium       23312
# economic      23184
# Name: count, dtype: int64

# %%
# Chart - 3 visualization code
# Average 'price' by 'flightType'
plt.figure(figsize=(12, 6))
sns.barplot(x='flightType', y='flight_price', data=df, estimator='mean')
plt.title('Average Price by Flight Type')
plt.xlabel('Flight Type')
plt.ylabel('Average Price')
plt.xticks(rotation=45)  # Rotate labels if necessary
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart was chosen because it effectively compares the average prices of different flight types, making it easy to visualize and compare the pricing trends across categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals that First Class has the highest average price, up to 1,100, followed by Premium Class with an average price of around 900, and Economy Class with an average price of 650.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights can help create a positive business impact by guiding pricing strategies and marketing efforts. Understanding the price distribution allows airlines to better position their products and optimize pricing for different customer segments, potentially increasing revenue and enhancing competitive advantage.

# %% [markdown]
# #### Chart - 4 Which age group has the highest likelihood of traveling?

# %%
# Chart - 4 visualization code
# Distribution of 'age'
plt.figure(figsize=(12, 6))
sns.histplot(df['age'], bins=30, kde=True, color='orange')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram was chosen because it effectively shows the distribution of age across different ranges, highlighting the frequency of each age group within the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals that age 46 has the highest frequency, with 5,100 occurrences, followed by age 63 with 4,300 occurrences, and age 21 with 3,900 occurrences. Most other ages have an average frequency between 2,000 and 3,000.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, understanding age distribution can help tailor marketing strategies and product offerings to better meet the needs of different age groups. This targeted approach can improve customer engagement and satisfaction, leading to a more effective and impactful business strategy.

# %% [markdown]
# #### Chart - 5 What is total number of days people like to stay in hotels?

# %%
df['days'].value_counts()
# Out:
# days
# 1    20342
# 4    20326
# 2    20220
# 3    20216
# Name: count, dtype: int64

# %%
# Chart - 5 visualization code
# Distribution of 'days'
plt.figure(figsize=(12, 6))
sns.histplot(df['days'], bins=30, kde=True, color='purple')
plt.title('Distribution of Length of Stay (Days)')
plt.xlabel('Days')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram was chosen to visualize the distribution of the length of stay in days because it effectively shows the frequency of stays across different durations, allowing us to understand common lengths of stay and any gaps in the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals that the most common lengths of stay are 1, 2, 3, and 4 days, each with a frequency of 20,000. There are no recorded stays for intermediate durations such as 1.5, 2.5, or 3.5 days.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help in optimizing hotel booking strategies and offerings. Understanding popular stay durations allows hotels to tailor their packages and promotions to match customer preferences, potentially increasing bookings and improving customer satisfaction.

# %% [markdown]
# #### Chart - 6 Find top 5 companies by spend?

# %%
# Chart - 6 visualization code
# Top 5 Companies by Total Spend
top_companies = df.groupby('company')['total'].sum().nlargest(5).reset_index()
plt.figure(figsize=(12, 8))
sns.barplot(data=top_companies, x='company', y='total', color= 'Pink')
plt.title('Top 5 Companies by Total Spend')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart was chosen to display the top 5 companies by total spend because it effectively highlights and compares the total spending of the leading companies, making it easy to see which companies have the highest expenditure.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals that there are only five companies in the top 10 list. 4You Travel Company has the highest total spend at over 1.4 k. Acme Factory follows with 0.7 k, while Wonka Company, Monsters CYA, and Umbrella LTDA each have total spends around 0.6 k.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, understanding which companies have the highest total spend can help in targeting high-value clients and tailoring business strategies to attract and retain these top spenders. This information can also assist in resource allocation and strategic planning to maximize revenue and strengthen relationships with key clients.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# Box Plot for 'gender' across 'total' spend
plt.figure(figsize=(12, 6))
sns.boxplot(x='gender', y='total', data= df)
plt.title('Box Plot of total Spend by Gender')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot was chosen to visualize the distribution of total spend across different genders because it effectively shows the spread, central tendency, and any potential outliers in spending for each gender.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals that spending is distributed within the same range across all genders, indicating similar spending patterns regardless of gender.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, understanding that spending patterns are similar across genders can help in developing uniform marketing strategies and pricing models. It ensures that business decisions are equitable and not biased towards a specific gender, leading to more balanced and effective business practices.

# %% [markdown]
# #### Chart - 8 How can we determine the proportion of different flight types among travelers?

# %%
df['flightType'].value_counts()
# Out:
# flightType
# firstClass    34608
# premium       23312
# economic      23184
# Name: count, dtype: int64

# %%
# Chart - 8 visualization code
# Pie Chart for 'flightType'
flight_type_counts = df['flightType'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(flight_type_counts, labels=flight_type_counts.index, autopct='%1.1f%%', startangle=140, explode=(0.03, 0.03, 0.03), shadow=True)
plt.title('Proportion of Flight Types')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart was chosen to display the proportion of each flight type because it visually represents the percentage share of each category within the whole, making it easy to see the relative sizes of different flight types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that First Class accounts for 42.7% of the total, Premium Class represents 28.7%, and Economy Class makes up 28.6%.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, understanding the distribution of flight types can guide airlines in optimizing their service offerings and marketing strategies. Knowing the proportion of each flight type helps in adjusting pricing strategies, improving inventory management, and tailoring promotions to enhance customer satisfaction and profitability.

# %% [markdown]
# #### Chart - 9 How do average flight prices vary across different agencies?

# %%
df['agency'].value_counts()
# Out:
# agency
# CloudFy        34820
# Rainbow        34784
# FlyingDrops    11500
# Name: count, dtype: int64

# %%
# Chart - 9 visualization code
# Average Flight Price by Agency
avg_flight_price_by_agency = df.groupby('agency')['flight_price'].mean().reset_index()
plt.figure(figsize=(8, 6))
sns.barplot(data=avg_flight_price_by_agency, x='agency', y='flight_price', color = 'Grey')
plt.title('Average Flight Price by Agency')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart was chosen to display the average flight price by agency because it effectively compares the average prices across different agencies, making it easy to see which agencies have higher or lower average prices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that FlyingDrops has the highest average flight price at around 1,150 USD. CloudFy and Rainbow have average flight prices of approximately 900 USD each.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, understanding the average flight prices by agency can help in pricing strategies and competitive positioning. Knowing which agencies charge higher or lower prices allows businesses to adjust their offers, target specific market segments, and develop competitive pricing strategies to attract more customers.

# %% [markdown]
# #### Chart - 10 What is the average hotel price in different locations?

# %%
df['place'].value_counts()
# Out:
# place
# Salvador (BH)          10188
# Rio de Janeiro (RJ)    10058
# Natal (RN)              9658
# Sao Paulo (SP)          9656
# Recife (PE)             8934
# Brasilia (DF)           8874
# Campo Grande (MS)       8666
# Aracaju (SE)            8410
# Florianopolis (SC)      6660
# Name: count, dtype: int64

# %%
# Chart - 10 visualization code
# Average Hotel Price by Place
avg_hotel_price_by_place = df.groupby('place')['hotel_price'].mean().reset_index()
plt.figure(figsize=(8, 6))
sns.barplot(data= avg_hotel_price_by_place, x='place', y='hotel_price')
plt.title('Average Hotel Price by Place')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart was chosen to display the average hotel price by place because it effectively compares the average prices across different locations, making it easy to identify which places have higher or lower hotel costs.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals that Campo Grande (MS) and Recife (PE) have the highest average hotel prices, around 320 USD. Salvador (BH) follows with an average price of 260 USD. Most other places have average hotel prices below 250 USD, with Brasília (DF) having the lowest at around 60 USD.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help in pricing strategies and marketing efforts. Understanding the average hotel prices in various locations allows businesses to adjust their pricing, target specific market segments, and develop promotional offers that align with local market conditions. This approach can enhance competitiveness and attract more customers.

# %%
df.columns
# Out:
# Index(['code', 'company', 'user_name', 'gender', 'age', 'travelCode', 'from',
#        'to', 'flightType', 'flight_price', 'time', 'distance', 'agency',
#        'flight_date', 'hotel_name', 'place', 'days', 'hotel_price', 'total',
#        'hotel_date'],
#       dtype='object')

# %% [markdown]
# #### Chart - 11 How do spending trends change over time?

# %%
# Chart - 11 visualization code
# Time Series Analysis of Total Spend Over Time
df['flight_date'] = pd.to_datetime(df['flight_date'])
total_spend_over_time = df.set_index('flight_date').resample('M')['total'].sum()
plt.figure(figsize=(10, 6))
total_spend_over_time.plot()
plt.title('Total Spend Over Time')
plt.xlabel('Date')
plt.ylabel('Total Spend')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A time series plot was chosen to visualize total spend over time because it effectively shows how spending trends change across different periods. This chart helps in identifying patterns, trends, and fluctuations in spending over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals that total spend was highest in January 2020 and decreased to zero by the end of July 2023. This indicates a significant decline in spending over the observed period.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, understanding the trend in total spend over time can help businesses identify periods of high and low spending. This information is valuable for adjusting strategies, forecasting future trends, and making data-driven decisions to manage finances and improve business performance.

# %% [markdown]
# #### Chart - 12 Which location has the highest average spending on accommodations by travelers?

# %%
# Chart - 12 visualization code
# Violin Plot for 'total' across 'place'
plt.figure(figsize=(12, 6))
sns.violinplot(x='place', y='total', data= df)
plt.title('Violin Plot of Total Spend by Place')
plt.xlabel('Place')
plt.ylabel('Total Spend')
plt.xticks(rotation=45)  # Rotate labels if necessary
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A violin plot was chosen to show the distribution of total spend by place because it provides a detailed view of both the density and distribution of spending across different locations, highlighting where people spend the most and the spread of expenditure.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals that Florianópolis (SC) and Recife (PE) have the highest total spend, around 1,300 USD. Salvador (BH) has an average spend of about 1US to 100 USD. Most other places have total spends below 1,000 USD. São Paulo shows a medium density of spending ranging from 150 to 550 USD, while Campo Grande (MS) has the lowest total spend with a range of 20 to 250 USD but with the highest density.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can guide businesses in targeting their marketing and pricing strategies. Knowing which places have the highest spending can help in focusing promotional efforts and optimizing pricing to attract high-spending customers. Additionally, understanding the distribution of spending can aid in better resource allocation and strategy development.

# %% [markdown]
# #### Chart - 13 In which location do people spend the most on accommodations?

# %%
# Chart - 13 visualization code
# Scatter Plot for Customer Segmentation
plt.figure(figsize=(12, 8))
sns.scatterplot(x='age', y='total', hue='gender', style='gender', data=df, alpha=0.7)
plt.title('Customer Segmentation by Age and Total Spend')
plt.xlabel('Age')
plt.ylabel('Total Spend')
plt.legend(title='Gender')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot was chosen to visualize customer segmentation by age and total spend because it allows for the analysis of spending patterns across different ages and genders, highlighting any correlations or clusters in the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals that, overall, there is little difference in spending patterns across age and gender groups. However, it shows that males aged between 32 and 36 are traveling the most, indicating a peak in total spend for this demographic.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help businesses tailor their marketing strategies and offers to target specific age and gender groups more effectively. By understanding which demographic spends the most, companies can develop targeted promotions and services to attract and retain high-spending customers.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# Select only the numerical columns for correlation calculation
numerical_data = df.select_dtypes(include=['number'])

# Calculate the correlation matrix
correlation_matrix = numerical_data.corr()

# Create a heatmap
plt.figure(figsize=(12, 8))  # Adjust the size as needed
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A heatmap was chosen to visualize the correlation matrix because it effectively displays the strength and direction of relationships between numerical variables in a clear and concise manner. The color gradient helps in quickly identifying strong or weak correlations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heatmap shows the correlation coefficients between different numerical variables. Strong correlations (close to +1 or -1) are highlighted in dark colors, while weak correlations (close to 0) are shown in lighter colors. This visualization helps identify which variables are closely related and which are not.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
# Select numerical columns for the pair plot
numerical_data = df.select_dtypes(include=['number'])

# Create a pair plot
sns.pairplot(numerical_data)
plt.suptitle('Pair Plot of Numerical Features', y=1.02)  # Adjust title position
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot was chosen to visualize the relationships between all pairs of numerical variables because it provides a comprehensive view of how each variable interacts with others. It displays scatter plots for each pair of variables and histograms for individual variables, allowing for the detection of patterns, correlations, and distributions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pair plot reveals how numerical features relate to one another through scatter plots and histograms. It helps in identifying trends, clusters, and correlations between variables. Any patterns or outliers in the data are visually apparent, providing insights into variable relationships and distributions.

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 1

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 2

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 3

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %%
# Handling Missing Values & Missing Value Imputation

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 2. Handling Outliers

# %%
# Handling Outliers & Outlier treatments

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 3. Categorical Encoding

# %%
# Encode your categorical columns

# %% [markdown]
# #### What all categorical encoding techniques have you used & why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Textual Data Preprocessing
# (It's mandatory for textual dataset i.e., NLP, Sentiment Analysis, Text Clustering etc.)

# %% [markdown]
# #### 1. Expand Contraction

# %%
# Expand Contraction

# %% [markdown]
# #### 2. Lower Casing

# %%
# Lower Casing

# %% [markdown]
# #### 3. Removing Punctuations

# %%
# Remove Punctuations

# %% [markdown]
# #### 4. Removing URLs & Removing words and digits contain digits.

# %%
# Remove URLs & Remove words and digits contain digits

# %% [markdown]
# #### 5. Removing Stopwords & Removing White spaces

# %%
# Remove Stopwords

# %%
# Remove White spaces

# %% [markdown]
# #### 6. Rephrase Text

# %%
# Rephrase Text

# %% [markdown]
# #### 7. Tokenization

# %%
# Tokenization

# %% [markdown]
# #### 8. Text Normalization

# %%
# Normalizing Text (i.e., Stemming, Lemmatization etc.)

# %% [markdown]
# ##### Which text normalization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 9. Part of speech tagging

# %%
# POS Taging

# %% [markdown]
# #### 10. Text Vectorization

# %%
# Vectorizing Text

# %% [markdown]
# ##### Which text vectorization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Manipulate Features to minimize feature correlation and create new features

# %% [markdown]
# #### 2. Feature Selection

# %%
# Select your features wisely to avoid overfitting

# %% [markdown]
# ##### What all feature selection methods have you used  and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 5. Data Transformation

# %% [markdown]
# #### Do you think that your data needs to be transformed? If yes, which transformation have you used. Explain Why?

# %%
# Transform Your data

# %% [markdown]
# ### 6. Data Scaling

# %%
# Scaling your data

# %% [markdown]
# ##### Which method have you used to scale you data and why?

# %% [markdown]
# ### 7. Dimesionality Reduction

# %% [markdown]
# ##### Do you think that dimensionality reduction is needed? Explain Why?

# %% [markdown]
# Answer Here.

# %%
# DImensionality Reduction (If needed)

# %% [markdown]
# ##### Which dimensionality reduction technique have you used and why? (If dimensionality reduction done on dataset.)

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 8. Data Splitting

# %%
# Split your data to train and test. Choose Splitting ratio wisely.

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 9. Handling Imbalanced Dataset

# %% [markdown]
# ##### Do you think the dataset is imbalanced? Explain Why.

# %% [markdown]
# Answer Here.

# %%
# Handling Imbalanced Dataset (If needed)

# %% [markdown]
# ##### What technique did you use to handle the imbalance dataset and why? (If needed to be balanced)

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1

# %%
# ML Model - 1 Implementation

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 2

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 3

# %%
# ML Model - 3 Implementation

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 3 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***8.*** ***Future Work (Optional)***

# %% [markdown]
# ### 1. Save the best performing ml model in a pickle file or joblib file format for deployment process.

# %%
# Save the File

# %% [markdown]
# ### 2. Again Load the saved model file and try to predict unseen data for a sanity check.

# %%
# Load the File and predict unseen data.

# %% [markdown]
# ### ***Congrats! Your model is successfully created and ready for deployment on a live server for a real user interaction !!!***

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
